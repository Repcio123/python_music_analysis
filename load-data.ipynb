# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('Spotify_Youtube.csv', index_col=0 )
data['Album_type'].unique().tolist()
# Out:
# ['album', 'single', 'compilation']

# %% [markdown]
# df = df.drop(df[(df['A'] == 0) & (df['B'] < 5)].index)

# %%
data.drop(labels=['Url_spotify', 'Album', 'Album_type', 'Uri', 'Url_youtube', 'Channel', 'Description', 'Licensed', 'official_video', 'Stream', 'Title',  ], inplace=True, axis=1)
data.dropna(inplace=True)
data = data.drop(data[data['Duration_ms'] >= 1200000].index)
data = data.drop(data[(data['Instrumentalness'] == 0) & (data['Loudness'] <= -10)].index)


data.sort_values('Speechiness', ascending=False)
# data.drop()
# Out:
#                        Artist  \
# 12321           Teufelskicker
# 9173                    Raffi
# 12319           Teufelskicker
# 1972                     TKKG
# 11722         Thomas Karallus
# ...                       ...
# 15595  White Noise Baby Sleep
# 15590  White Noise Baby Sleep
# 15588  White Noise Baby Sleep
# 13842  White Noise for Babies
# 13848  White Noise for Babies
#
#                                                    Track  Danceability  \
# 12321                  96 - Tausendundein Tor! - Teil 08         0.475
# 9173                                    Brush Your Teeth         0.832
# 12319                  96 - Tausendundein Tor! - Teil 02         0.613
# 1972           225 - Tanz mit der Giftschlange - Teil 04         0.468
# 11722            Drachenzähmen leicht gemacht 3 - Teil 1         0.620
# ...                                                  ...           ...
# 15595  White Noise Relaxation for Calming Down Fussy ...         0.000
# 15590           Pure Brown Noise - Loopable with no fade         0.000
# 15588          Clean White Noise - Loopable with no fade         0.000
# 13842            Air Conditioner - Loopable with no fade         0.000
# 13848              Clean White Noise - Loopable, No Fade         0.000
#
#          Energy   Key  Loudness  Speechiness  Acousticness  Instrumentalness  \
# 12321  0.901000   6.0    -7.625        0.940         0.873          0.000000
# 9173   0.216000   4.0   -24.799        0.934         0.511          0.000054
# 12319  0.775000  11.0    -7.467        0.912         0.460          0.000000
# 1972   0.545000   1.0   -14.122        0.906         0.256          0.000028
# 11722  0.607000   1.0    -9.632        0.902         0.629          0.000000
# ...         ...   ...       ...          ...           ...               ...
# 15595  0.373000  10.0   -16.469        0.000         0.153          0.999000
# 15590  0.001250   1.0   -27.592        0.000         0.908          1.000000
# 15588  0.003420   8.0   -28.460        0.000         0.791          1.000000
# 13842  0.000055  10.0   -21.995        0.000         0.921          1.000000
# 13848  0.003420   8.0   -28.460        0.000         0.791          1.000000
#
#        Liveness  Valence    Tempo  Duration_ms      Views   Likes  Comments
# 12321     0.960    0.464   78.865     181680.0     6933.0    33.0       0.0
# 9173      0.107    0.490   81.910      72173.0  3635478.0  5732.0       0.0
# 12319     0.378    0.536  158.124     182720.0     3455.0    21.0       0.0
# 1972      0.141    0.472   84.530     180093.0     1628.0    17.0       1.0
# 11722     0.655    0.680   91.375     196373.0    62392.0   501.0       4.0
# ...         ...      ...      ...          ...        ...     ...       ...
# 15595     0.726    0.000    0.000     593754.0   376087.0   561.0       0.0
# 15590     0.111    0.000    0.000      72223.0   290014.0   674.0       0.0
# 15588     0.111    0.000    0.000      90228.0     1492.0    18.0       0.0
# 13842     0.114    0.000    0.000     108527.0      407.0     1.0       0.0
# 13848     0.111    0.000    0.000      90228.0     1492.0    18.0       0.0
#
# [19231 rows x 16 columns]

# %%
data.to_csv('spotify-yt-fixed.csv')
