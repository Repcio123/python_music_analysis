# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('Spotify_Youtube.csv', index_col=0 )
data['Album_type'].unique().tolist()
# Out:
# ['album', 'single', 'compilation']

# %% [markdown]
# df = df.drop(df[(df['A'] == 0) & (df['B'] < 5)].index)

# %%
data.drop(labels=['Url_spotify', 'Album', 'Album_type', 'Uri', 'Url_youtube', 'Channel', 'Description', 'Licensed', 'official_video', 'Stream', 'Title',  ], inplace=True, axis=1)
data.dropna(inplace=True)
data = data.drop(data[data['Duration_ms'] >= 1200000].index)
data = data.drop(data[(data['Instrumentalness'] == 0) & (data['Loudness'] <= -10)].index)
data = data.drop(data[data['Speechiness'] >= 0.5].index)

data.sort_values('Speechiness', ascending=False)
# data.drop()
# Out:
#                        Artist                                       Track  \
# 15541                  Aleman                                       Rucón
# 16505         Earl Sweatshirt  Hive (feat. Vince Staples & Casey Veggies)
# 13208                  Skepta                           What Do You Mean?
# 9709                  Luciano            West Connect (feat. Central Cee)
# 3517             Cypress Hill                             Tequila Sunrise
# ...                       ...                                         ...
# 13840  White Noise for Babies    Pure Brown Noise - Loopable with no fade
# 15588  White Noise Baby Sleep   Clean White Noise - Loopable with no fade
# 13842  White Noise for Babies     Air Conditioner - Loopable with no fade
# 13844  White Noise for Babies        Shower Sound - Loopable Without Fade
# 13845  White Noise for Babies    Soothing White Noise - Loopable, No Fade
#
#        Danceability    Energy   Key  Loudness  Speechiness  Acousticness  \
# ...

# %%
data.to_csv('spotify-yt-fixed.csv')
