# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('Spotify_Youtube.csv', index_col=0 )
data.drop(labels=['Url_spotify', 'Album', 'Album_type', 'Uri', 'Url_youtube', 'Channel', 'Description', 'Licensed', 'official_video', 'Stream', 'Title',  ], inplace=True, axis=1)
data.dropna(inplace=True)

data.sort_values('Views', ascending=False)
data.drop()
# Out:
#                  Artist                                              Track  \
# 1147         Luis Fonsi                                          Despacito
# 365        Daddy Yankee                                          Despacito
# 12452        Ed Sheeran                                       Shape of You
# 14580      Charlie Puth                 See You Again (feat. Charlie Puth)
# 12469       Wiz Khalifa                 See You Again (feat. Charlie Puth)
# ...                 ...                                                ...
# 13406     Peter Groeger                Kapitel 2.4 - Der Kaiser von Dallas
# 13408     Peter Groeger                Kapitel 3.2 - Der Kaiser von Dallas
# 13401     Peter Groeger                Kapitel 2.3 - Der Kaiser von Dallas
# 11022    Christian Rode                Kapitel 2.2 - Sindbad der Seefahrer
# 5898   Santiago Ziesmer  Kapitel 5.2 & Kapitel 6.1 - Die kleine Hexe - ...
#
# ...

# %%
data.to_csv('spotify-yt-fixed.csv')
